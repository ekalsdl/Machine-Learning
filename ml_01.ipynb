# %%
# 데이터 준비

import csv
f1 = open("train.csv", 'r')
data1 = csv.reader(f1)

header = next(data1)
stock_price_index = []
gold_price = []


for row in data1:
    stock_price_index.append(float(row[0]))
    gold_price.append(float(row[1]))

f1.close()

# 데이터 전처리

import numpy as np
x = np.array(stock_price_index)
y = np.array(gold_price)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42)

x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=5, include_bias=False)
poly.fit(x_train)
x_train_poly= poly.transform(x_train)
x_test_poly= poly.transform(x_test)
print(x_train_poly.shape)

lr = LinearRegression()
lr.fit(x_train_poly, y_train)

print(lr.score(x_train_poly, y_train))
print(lr.score(x_test_poly, y_test))

f2 = open("test.csv", 'r')
data2 = csv.reader(f2)

header = next(data2)
z = []
for row in data2:
    z.append(float(row[0]))

f2.close()

import pandas as pd
import numpy as np

df = pd.read_csv("submission.csv")

df.dropna(axis=1, inplace=True)

y_pred = lr.predict(x_test_poly)

df["gold price"] = y_pred
df.to_csv("new_submission.csv", index=False)
# Out:
# (2231, 5)
# 0.7566446612762422
# 0.7882465875768419

# %%
# 데이터 준비

import csv
f1 = open("train.csv", 'r')
data1 = csv.reader(f1)

header = next(data1)
stock_price_index = []
gold_price = []


for row in data1:
    stock_price_index.append(float(row[0]))
    gold_price.append(float(row[1]))

f1.close()

# 데이터 전처리

import numpy as np
x = np.array(stock_price_index)
y = np.array(gold_price)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42)

x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=5, include_bias=False)
poly.fit(x_train)
x_train_poly= poly.transform(x_train)
x_test_poly= poly.transform(x_test)
print(x_train_poly.shape)

lr = LinearRegression()
lr.fit(x_train_poly, y_train)

print(lr.score(x_train_poly, y_train))
print(lr.score(x_test_poly, y_test))

f2 = open("test.csv", 'r')
data2 = csv.reader(f2)

header = next(data2)
z = []
for row in data2:
    z.append(float(row[0]))

f2.close()

import pandas as pd
import numpy as np

df = pd.read_csv("submission.csv")

df.dropna(axis=1, inplace=True)

y_pred = lr.predict(x_test_poly)

df["gold price"] = y_pred
df.to_csv("new_submission.csv", index=False)
# Out:
# (2231, 5)
# 0.7566446612762422
# 0.7882465875768419
